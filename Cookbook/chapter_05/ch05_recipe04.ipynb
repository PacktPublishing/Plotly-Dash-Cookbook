# %% [markdown]
# # Creating Sunburst Charts

# %%
import plotly.express as px
data = dict(
    character=["My Goals", "Health", "Career", "Personal", "Finance", 
               "Exercise", "Diet", "Sleep", 
               "New Skills", "Networking", 
               "Family", "Friends", 
               "Investing", "Saving"
               ],
    parent   =["", "My Goals", "My Goals", "My Goals", "My Goals" ,
               "Health", "Health", "Health",  "Career",  "Career", "Personal", "Personal", "Finance", "Finance"],
    value=[0, 25, 25, 25, 25, 10, 10, 10, 10, 10, 10, 10, 10, 10])

fig = px.sunburst(
    data,
    names='character',
    parents='parent',
    # values='value',
)
fig.show()

# %%
import plotly.express as px
import numpy as np
df = px.data.gapminder().query("year == 2007")
fig = px.sunburst(df, path=['continent', 'country'], values='pop',
                  color='lifeExp', hover_data=['iso_alpha'],
                  color_continuous_scale='RdBu',
                  color_continuous_midpoint=np.average(df['lifeExp'], weights=df['pop']))
fig.show()

# %%
import plotly.express as px
import numpy as np
df = px.data.gapminder().query("year == 2007")
fig = px.sunburst(df, path=['continent', 'country'], values='pop',
                  color='lifeExp', hover_data=['iso_alpha'],
                  color_continuous_scale='RdBu',
                  color_continuous_midpoint=np.average(df['lifeExp'], weights=df['pop']))
fig.show()
