# %% [markdown]
# # Fetching Data from APIs

# %% [markdown]
# In this recipe you will learn to retrieve data for your visualization projects using APIs (Application Programming Interfaces). This will allow you to leverage the millions of APIs that are available online, with websites like Reddit, X (formerly Twitter), and Facebook offering access to certain data sets through their APIs.

# %% [markdown]
# ## Getting ready
#
# For this recipe, we will use the Python library `requests`. If you use pip to manage your Python packages, you can install the requests library using the following command
#
# `pip install requests`

# %% [markdown]
# ## How to do it
#
# 1. Import the `requests` module

# %%
import requests

# %% [markdown]
# 2. Define the API enpoint from which you want to request the data. For this example, we are goig to use an URL to get GitHub’s public timeline.

# %%
url = 'https://api.github.com/events'

# %% [markdown]
# 3. Submit a request by using the method `get`

# %%
response = requests.get(url=url)
type(response)
# Out:
# requests.models.Response

# %% [markdown]
# 4. Check the status code of the response

# %%
print(response.status_code)
# Out:
# 200

# %% [markdown]
# Every request sent to a web-server returns a status code indicating what happened. Some common codes relevant to GET requests:
#
# - 200: Everything went okay, and the result (if any) has been returned.
# - 301: The server is redirecting you to a different endpoint. This can happen when a company switches domain names, or an endpoint name is changed.
# - 400: The server thinks you made a bad request. This happens when you send incorrect data or make other client-side errors.
# - 401: The server thinks you're not authenticated. Many APIs require login credentials, so this happens when you don't send the right credentials to access an API.
# - 403: The resource you're trying to access is forbidden: you don't have the right permissions to see it.
# - 404: The resource you tried to access wasn't found on the server.
# - 503: The server is not ready to handle the request.

# %% [markdown]
# 5. Parse the response content using `text`. This will simply show the result as a `string`.

# %%
response.text
# Out:
# '[{"id":"40321532364","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":735031782,"name":"Thorthon0/TelegramV2rayCollector","url":"https://api.github.com/repos/Thorthon0/TelegramV2rayCollector"},"payload":{"repository_id":735031782,"push_id":19407459162,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"7c3fe843db0374ad425e88219840b44609a9a1ae","before":"157906abe9090f1c39cafa1e967efd0a71eecee7","commits":[{"sha":"7c3fe843db0374ad425e88219840b44609a9a1ae","author":{"email":"yebekhe@gmail.com","name":"yebekhe"},"message":"🚀 Servers Updated - 2024-07-21 01:49:50","distinct":true,"url":"https://api.github.com/repos/Thorthon0/TelegramV2rayCollector/commits/7c3fe843db0374ad425e88219840b44609a9a1ae"}]},"public":true,"created_at":"2024-07-20T22:19:52Z"},{"id":"40321532347","type":"PushEvent","actor":{"id":104646451,"login":"aws-aemilia-mxp","display_login":"aws-aemilia-mxp","gravatar_id":"","url":"https://api.github.com/users/aws-aemilia-mxp","avatar_url":"https://avatars.githubusercontent.com/u/104646451?"},"repo":{"id":810472100,"name":"aws-aemilia-mxp/Github-PR-Commit-Integration-Test-DoNotTouch-GitHubAutoBuildPrPreviewCanaryTest-v1-prod-eu-south-1","url":"https://api.github.com/repos/aws-aemilia-mxp/Github-PR-Commit-Integration-Test-DoNotTouch-GitHubAutoBuildPrPreviewCanaryTest-v1-prod-eu-south-1"},"payload":{"repository_id":810472100,"push_id":19407459151,"size":1,"distinct_size":1,"ref":"refs/heads/GitHubAutoBuildPrPreviewCanaryTestpr-prod-1721513990093","head":"5444eabb1d59b2d32b4d9ac2c885c4ed7b883739","before":"1fc20222905d8914ce76155e3251adab5b781af6","commits":[{"sha":"5444eabb1d59b2d32b4d9ac2c885c4ed7b883739","author":{"email":"104646451+aws-aemilia-mxp@users.noreply.github.com","name":"aws-aemilia-mxp"},"message":"commit from integ tests","distinct":true,"url":"https://api.github.com/repos/aws-aemilia-mxp/Github-PR-Commit-Integration-Test-DoNotTouch-GitHubAutoBuildPrPreviewCanaryTest-v1-prod-eu-south-1/commits/5444eabb1d59b2d32b4d9ac2c885c4ed7b883739"}]},"public":true,"created_at":"2024-07-20T22:19:52Z"},{"id":"40321532348","type":"WatchEvent","actor":{"id":167259106,"login":"Robbin1998s","display_login":"Robbin1998s","gravatar_id":"","url":"https://api.github.com/users/Robbin1998s","avatar_url":"https://avatars.githubusercontent.com/u/167259106?"},"repo":{"id":95901229,"name":"inbo/etn","url":"https://api.github.com/repos/inbo/etn"},"payload":{"action":"started"},"public":true,"created_at":"2024-07-20T22:19:52Z","org":{"id":2735610,"login":"inbo","gravatar_id":"","url":"https://api.github.com/orgs/inbo","avatar_url":"https://avatars.githubusercontent.com/u/2735610?"}},{"id":"40321532360","type":"PushEvent","actor":{"id":149879998,"login":"graphfactory","display_login":"graphfactory","gravatar_id":"","url":"https://api.github.com/users/graphfactory","avatar_url":"https://avatars.githubusercontent.com/u/149879998?"},"repo":{"id":714277029,"name":"graphfactory/graphfactory.github.io","url":"https://api.github.com/repos/graphfactory/graphfactory.github.io"},"payload":{"repository_id":714277029,"push_id":19407459164,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"85731379a590d158e32ad3c2dd495f5af8ea950f","before":"379d8a8b7ff1c5ee52cd90e93d93038cf172d016","commits":[{"sha":"85731379a590d158e32ad3c2dd495f5af8ea950f","author":{"email":"149879998+graphfactory@users.noreply.github.com","name":"graphfactory"},"message":"Update index.html","distinct":true,"url":"https://api.github.com/repos/graphfactory/graphfactory.github.io/commits/85731379a590d158e32ad3c2dd495f5af8ea950f"}]},"public":true,"created_at":"2024-07-20T22:19:52Z"},{"id":"40321532365","type":"PushEvent","actor":{"id":2299951,"login":"pietroalbini","display_login":"pietroalbini","gravatar_id":"","url":"https://api.github.com/users/pietroalbini","a ...

# %% [markdown]
# 6. Parse the response content in `JSON` format using the method `json`. This will return a list, as we can see by checking the type of the result.

# %%
result = response.json()
type(result)
# Out:
# list

# %% [markdown]
# 7. Check the first element of the response

# %%
result[0]
# Out:
# {'id': '40321532364',
#  'type': 'PushEvent',
#  'actor': {'id': 41898282,
#   'login': 'github-actions[bot]',
#   'display_login': 'github-actions',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/github-actions[bot]',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#  'repo': {'id': 735031782,
#   'name': 'Thorthon0/TelegramV2rayCollector',
#   'url': 'https://api.github.com/repos/Thorthon0/TelegramV2rayCollector'},
#  'payload': {'repository_id': 735031782,
#   'push_id': 19407459162,
#   'size': 1,
#   'distinct_size': 1,
#   'ref': 'refs/heads/main',
#   'head': '7c3fe843db0374ad425e88219840b44609a9a1ae',
#   'before': '157906abe9090f1c39cafa1e967efd0a71eecee7',
#   'commits': [{'sha': '7c3fe843db0374ad425e88219840b44609a9a1ae',
#     'author': {'email': 'yebekhe@gmail.com', 'name': 'yebekhe'},
#     'message': '🚀 Servers Updated - 2024-07-21 01:49:50',
#     'distinct': True,
#     'url': 'https://api.github.com/repos/Thorthon0/TelegramV2rayCollector/commits/7c3fe843db0374ad425e88219840b44609a9a1ae'}]},
#  'public': True,
#  'created_at': '2024-07-20T22:19:52Z'}

# %%
nasaKey = "your-key-here"

# %%
params = {'api_key': nasaKey}
response = requests.get('https://api.nasa.gov/planetary/apod', params=params)

# %%
response

# %%
response.json()
